# %%
import turtle
t = turtle.Turtle()
def rect(x,y,a):
 t.up()
 t.home()
 t.forward(x)
 t.left(90)
 t.forward(y)
 t.down()
 for i in range(4):
  t.forward(a)
  t.left(-90)
  
 def func():
  i = 3
  return i
  
 def func(v):
  i = v + 3
  return i
  
 func(5)
 
 func(15)
 
 s = 0
 for x in range(1,101):
  s += x
  
 s
 
 def yline(x,y,a):
  t.up()
  t.home()
  t.forward(x)
  t.left(90)
  t.forward(y)
  t.down()
  t.forward(a)
  
  t.clear()
  rect(0,0,100)
  rect(-120,0,100)
  
 t.clear()
 rect(110,-110,110)
 rect(110,0,100)
 rect(0,-110,100)
 rect(0,0,100)
 t.clear()
 rect(110,-110,100)
 rect(110,0,100)
 rect(0,-110,100)
 rect(0,0,100)
  
 t.home()
 t.clear()
 def circle(x,y,r):
  t.up()
  t.home()
  t.forward(x)
  t.left(90)
  t.forward(y)
  t.forward(r)
  t.left(90)
  t.down()
  t.circle(r)
  
  circle(100,100,50)
